# %%
import os
import sys
import math

# !export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/usr/local/cuda/lib64/

import time
from Demic.util.parse_config import parse_config
from test import model_test
import tensorflow as tf

# sys.argv = ['fetal_brain_seg.py',
#             '--input_names', 'demo_data/image5.nii.gz', 'demo_data/image6.nii.gz',
#             '--segment_output_names', 'demo_data/image5_segment.nii.gz', 'demo_data/image6_segment.nii.gz']
# Out:
# /autofs/space/bal_004/users/jd1677/anaconda3/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /autofs/space/bal_004/users/jd1677/anaconda3/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /autofs/space/bal_004/users/jd1677/anaconda3/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# ...

# %%
# input_names = ['demo_data/image5.nii.gz', 'demo_data/image6.nii.gz']
# seg_names = ['demo_data/image5_segment.nii.gz', 'demo_data/image6_segment.nii.gz']

# # input_names = ['demo_data/image1.nii.gz', 'demo_data/image2.nii.gz']
# # seg_names = ['demo_data/image1_segment.nii.gz', 'demo_data/image2_segment.nii.gz']


# data_config = {}
# for i in range(len(input_names)):
#     img_i = f'image_{i}'
#     data_config[img_i] = {
#         'input': input_names[i],
#         'segment_output': seg_names[i]
#     }

import os

data_folder = 'data/'  # Change this to your data folder path

input_files = [file for file in os.listdir(data_folder) if file.endswith('.nii.gz')]

data_config = {}
for input_file in input_files:
    input_path = os.path.join(data_folder, input_file)
    segment_output = os.path.splitext(input_file)[0] + '_segment.nii.gz'
    segment_output_path = os.path.join(data_folder, segment_output)
    
    data_config[input_file] = {
        'input': input_path,
        'segment_output': segment_output_path
    }

    
net_config_file = 'cfg_net.txt'
net_config = parse_config(net_config_file)
model_test(net_config, data_config)
# Out:
# network1 net_type PNet PNet
# network1 net_name pnet pnet
# network1 data_shape [1, 96, 96, 1] [1, 96, 96, 1]
# network1 label_shape [1, 96, 96, 1] [1, 96, 96, 1]
# network1 class_num 2 2
# network1 model_file model/detect/pnet.ckpt model/detect/pnet.ckpt
# network2 net_type PNet PNet
# network2 net_name pnet_seg pnet_seg
# network2 data_shape [1, 96, 96, 1] [1, 96, 96, 1]
# network2 label_shape [1, 96, 96, 1] [1, 96, 96, 1]
# network2 class_num 2 2
# network2 model_file model/segment/pnet_seg.ckpt model/segment/pnet_seg.ckpt
# detect_testing fix_batch_size False False
# detect_testing use_depth_as_batch_size True True
# detect_testing batch_size 80 80
# detect_testing resize_input True True
# detect_testing resize_input_to_given_shape_in_2d [96, 96] [96, 96]
# detect_testing shape_mode 1 1
# segment_testing fix_batch_size False False
# segment_testing use_depth_as_batch_size True True
# segment_testing batch_size 40 40
# segment_testing resize_input True True
# ...

# %%
# !which python
# !conda install -c conda-forge simpleitk -y
